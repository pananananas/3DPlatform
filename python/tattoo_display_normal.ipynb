# %%
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from ipywidgets import interact
from PIL import Image
import scipy.ndimage
import numpy as np

# %%
data = np.load('imgs/hand2.npy')
hand_image = Image.open('imgs/hand2.jpeg')
tattoo_image = Image.open('imgs/tattoo.png')

# %%
data.shape
# Out:
# (4032, 3024, 3)

# %%
mask = np.isnan(data)

# %%
data_nan_replaced = np.copy(data)
data_nan_replaced[mask] = 0

# %%
plt.figure(figsize=(10, 10))
plt.imshow(data_nan_replaced)
plt.title('Normal Map with NaN Values Handled')
plt.axis('off')  # Hide the axis

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2690338..1.1742023].
